# %% [markdown]
# <a href="https://colab.research.google.com/github/dev-singh-chauhan/EDA_Practical/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('zomato.csv', encoding='latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# # **In Data Analysis what all things we do**
#
#
# 1.   Missing Values
# 2.   Explore about the numerical values
# 3.   Explore about catagorical Variable
# 4.   Finding Relationship between features

# %%
# Missing Values
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['Cuisines']

# %%
from pickle import FALSE
sns.heatmap(df.isnull(),yticklabels=FALSE,cmap='viridis')
# Out:
# <Axes: >

# %%
# !unzip /content/Country_code.zip
# Out:
# Archive:  /content/Country_code.zip
#   inflating: wikipedia-iso-country-codes.csv

# %%
df_countrycode = pd.read_csv('/content/wikipedia-iso-country-codes.csv')
df_countrycode.head()
# Out:
#   English short name lower case Alpha-2 code Alpha-3 code  Numeric code  \
# 0                   Afghanistan           AF          AFG             4
# 1                 Åland Islands           AX          ALA           248
# 2                       Albania           AL          ALB             8
# 3                       Algeria           DZ          DZA            12
# 4                American Samoa           AS          ASM            16
#
#       ISO 3166-2
# 0  ISO 3166-2:AF
# 1  ISO 3166-2:AX
# 2  ISO 3166-2:AL
# 3  ISO 3166-2:DZ
# 4  ISO 3166-2:AS

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
final_df = pd.merge(df,df_countrycode,left_on = 'Country Code',how='left',right_on='Numeric code')

# %%
final_df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Price range Aggregate rating Rating color  \
# 0  French, Japanese, Desserts  ...            3              4.8   Dark Green
# 1                    Japanese  ...            3              4.5   Dark Green
#
# ...

# %%
# To check Datatypes
final_df.dtypes
# Out:
# Restaurant ID                      int64
# Restaurant Name                   object
# Country Code                       int64
# City                              object
# Address                           object
# Locality                          object
# Locality Verbose                  object
# Longitude                        float64
# Latitude                         float64
# Cuisines                          object
# Average Cost for two               int64
# Currency                          object
# Has Table booking                 object
# Has Online delivery               object
# Is delivering now                 object
# Switch to order menu              object
# Price range                        int64
# Aggregate rating                 float64
# Rating color                      object
# Rating text                       object
# Votes                              int64
# English short name lower case     object
# Alpha-2 code                      object
# ...

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'English short name lower case', 'Alpha-2 code',
#        'Alpha-3 code', 'Numeric code', 'ISO 3166-2'],
#       dtype='object')

# %%
city_names=final_df.Currency.value_counts().index

# %%
#plot some charts
city_values = final_df.City.value_counts().values

# %%
#pie charts top 3 countries
plt.pie(city_values[:3],labels=city_names[:3],autopct='%1.f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7b1a3dbe4e30>,
# ...
#  [Text(-0.6836226235765238, 0.8617772963674262, 'Indian Rupees(Rs.)'),
#   Text(0.24897521967717012, -1.07145291076496, 'Dollar($)'),
#   Text(0.9941444825293274, -0.47082560238000676, 'Pounds(\x8c£)')],
#  [Text(-0.3728850674053766, 0.4700603434731415, '71%'),
#   Text(0.13580466527845642, -0.5844288604172508, '15%'),
#   Text(0.5422606268341785, -0.2568139649345491, '14%')])
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 140 (\x8c) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 140 (\x8c) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Observation:-
## Zomato maximun sales are from india then from uk then usa
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'English short name lower case', 'Alpha-2 code',
#        'Alpha-3 code', 'Numeric code', 'ISO 3166-2'],
#       dtype='object')

# %%
final_df.groupby([ 'Aggregate rating', 'Rating color', 'Rating text']).size()
# Out:
# Aggregate rating  Rating color  Rating text
# 0.0               White         Not rated      2148
# 1.8               Red           Poor              1
# 1.9               Red           Poor              2
# 2.0               Red           Poor              7
# 2.1               Red           Poor             15
# 2.2               Red           Poor             27
# 2.3               Red           Poor             47
# 2.4               Red           Poor             87
# 2.5               Orange        Average         110
# 2.6               Orange        Average         191
# 2.7               Orange        Average         250
# 2.8               Orange        Average         315
# 2.9               Orange        Average         381
# 3.0               Orange        Average         468
# 3.1               Orange        Average         519
# 3.2               Orange        Average         522
# 3.3               Orange        Average         483
# ...

# %%
ratings  =final_df.groupby([ 'Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
#Obseravations
''' 1. when rating is between 4.5 - 4.9 = Excellent
    2. when rating is between 4.0 - 4.4 = Very Good
    3. when rating is between 3.5 - 3.9 = Good
    4. when rating is between 2.5 - 3.4 = Average
    5. when rating is between 1.8 - 2.4 = Poor
'''
# Out:
# ' 1. when rating is between 4.5 - 4.9 = Excellent\n    2. when rating is between 4.0 - 4.4 = Very Good\n    3. when rating is between 3.5 - 3.9 = Good\n    4. when rating is between 2.5 - 3.4 = Average\n    5. when rating is between 1.8 - 2.4 = Poor\n'

# %%
# now ploting the ratings in a bar plot for visualization
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12,6)
sns.barplot(x = "Aggregate rating" , y = "Rating Count" , data = ratings)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
sns.barplot(x = "Aggregate rating" , y = "Rating Count" ,hue= 'Rating color', data = ratings)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
sns.barplot(x = "Aggregate rating" , y = "Rating Count" ,hue= 'Rating color', palette=['Black', 'Red', 'Orange','Yellow','Green','Green'], data = ratings)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %% [markdown]
# # **Observation**
#
#
# 1.   Not Rated count is very high
# 2.   Maximum Number of ratings is in between 2.5 to 3.4

# %%
## count plot
sns.countplot(x='Rating color',data=ratings,palette=['Black', 'Red', 'Orange','Yellow','Green','Green'])
# Out:
# /tmp/ipython-input-1145025951.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rating color',data=ratings,palette=['Black', 'Red', 'Orange','Yellow','Green','Green'])
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
# find the countries name that has given 0 ratings
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'English short name lower case', 'Alpha-2 code',
#        'Alpha-3 code', 'Numeric code', 'ISO 3166-2'],
#       dtype='object')

# %%
final_df[final_df['Rating color'] == 'White'].groupby(['Country Code','City']).size().reset_index()
# Out:
#     Country Code            City     0
# 0              1       Faridabad   100
# 1              1       Ghaziabad     2
# 2              1         Gurgaon   228
# 3              1       New Delhi  1425
# 4              1           Noida   384
# 5             30       Brasí_lia     1
# 6             30  Rio de Janeiro     1
# 7             30      Sí£o Paulo     3
# 8            215      Birmingham     1
# 9            216       Davenport     2
# 10           216       Pocatello     1

# %%
# Which currency is used by which country
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'English short name lower case', 'Alpha-2 code',
#        'Alpha-3 code', 'Numeric code', 'ISO 3166-2'],
#       dtype='object')

# %%
final_df.groupby(['Country Code','Currency']).size().reset_index()
# Out:
#     Country Code                Currency     0
# 0              1      Indian Rupees(Rs.)  8652
# 1             14               Dollar($)    24
# 2             30      Brazilian Real(R$)    60
# 3             37               Dollar($)     4
# 4             94  Indonesian Rupiah(IDR)    21
# 5            148           NewZealand($)    40
# 6            162        Botswana Pula(P)    22
# 7            166         Qatari Rial(QR)    20
# 8            184               Dollar($)    20
# 9            189                 Rand(R)    60
# 10           191   Sri Lankan Rupee(LKR)    20
# 11           208        Turkish Lira(TL)    34
# 12           214      Emirati Diram(AED)    60
# 13           215              Pounds(£)    80
# 14           216               Dollar($)   434

# %%
# which country do have online delivery
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'English short name lower case', 'Alpha-2 code',
#        'Alpha-3 code', 'Numeric code', 'ISO 3166-2'],
#       dtype='object')

# %%
final_df.groupby(['Has Online delivery','Country Code']).size().reset_index().value_counts()
# Out:
# Has Online delivery  Country Code  0
# No                   1             6229    1
#                      14            24      1
#                      30            60      1
#                      37            4       1
#                      94            21      1
#                      148           40      1
#                      162           22      1
#                      166           20      1
#                      184           20      1
#                      189           60      1
#                      191           20      1
#                      208           34      1
#                      214           32      1
#                      215           80      1
#                      216           434     1
# Yes                  1             2423    1
#                      214           28      1
# Name: count, dtype: int64

# %%
# Pie chart for cities distributions
city_names = final_df.City.value_counts().index
city_values = final_df.City.value_counts().values
plt.pie(city_values[:5],labels=city_names[:5],autopct='%1.f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7b1a304e0b00>,
# ...
#  [Text(-0.6145353730323401, 0.9123301350344637, 'New Delhi'),
#   Text(0.06236774886414425, -1.0982305149200777, 'Gurgaon'),
#   Text(0.878904221413572, -0.6614585169014024, 'Noida'),
#   Text(1.0922218482114119, -0.1305811406354216, 'Faridabad'),
#   Text(1.099946277419523, -0.010871374841004297, 'Ghaziabad')],
#  [Text(-0.33520111256309454, 0.4976346191097074, '69%'),
#   Text(0.03401877210771504, -0.5990348263200423, '14%'),
#   Text(0.479402302589221, -0.36079555467349217, '14%'),
#   Text(0.5957573717516791, -0.07122607671022996, '3%'),
#   Text(0.5999706967742853, -0.00592984082236598, '0%')])

# %%
# top 10 cusinies
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'English short name lower case', 'Alpha-2 code',
#        'Alpha-3 code', 'Numeric code', 'ISO 3166-2'],
#       dtype='object')

# %%
# Finding top 10 Cuisines
final_df['Cuisines'].value_counts().head(10)
# Out:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64

# %% [markdown]
# # **Black Friday Dataset EDA and Feature Engineering**
#
#
#  *  Cleaning and preparing the data for model training

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# !unzip /content/black_friday.zip
# Out:
# Archive:  /content/black_friday.zip
#   inflating: test.csv
#   inflating: train.csv

# %%
df_train = pd.read_csv('/content/train.csv')
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %% [markdown]
# # We have to build a model which perdict the purchase amount of customer againt various product

# %%
df_test = pd.read_csv('/content/test.csv')
df_test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
merged_df = pd.concat([df_train,df_test])
merged_df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 783667 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  object
#  3   Age                         783667 non-null  object
#  4   Occupation                  783667 non-null  int64
#  5   City_Category               783667 non-null  object
#  6   Stay_In_Current_City_Years  783667 non-null  object
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          537685 non-null  float64
#  10  Product_Category_3          237858 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# ...

# %%
merged_df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  7.836670e+05  783667.000000   783667.000000       783667.000000
# mean   1.003029e+06       8.079300        0.409777            5.366196
# std    1.727267e+03       6.522206        0.491793            3.878160
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001519e+06       2.000000        0.000000            1.000000
# 50%    1.003075e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       537685.000000       237858.000000  550068.000000
# mean             9.844506           12.668605    9263.968713
# std              5.089093            4.125510    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
merged_df.drop(["User_ID"],axis=1,inplace=True)

# %%
merged_df.head()
# Out:
#   Product_ID Gender   Age  Occupation City_Category  \
# 0  P00069042      F  0-17          10             A
# 1  P00248942      F  0-17          10             A
# 2  P00087842      F  0-17          10             A
# 3  P00085442      F  0-17          10             A
# 4  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
# fixing the catagorical features
pd.get_dummies(merged_df['Gender'])
# Out:
#             F      M
# 0        True  False
# 1        True  False
# 2        True  False
# 3        True  False
# 4       False   True
# ...       ...    ...
# 233594   True  False
# 233595   True  False
# 233596   True  False
# 233597   True  False
# 233598   True  False
#
# [783667 rows x 2 columns]

# %%
# catagorical variablr Genral
merged_df['Gender']  = merged_df['Gender'].map({'F':0,'M':1})

# %%
merged_df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042       0  0-17          10             A
# 1  P00248942       0  0-17          10             A
# 2  P00087842       0  0-17          10             A
# 3  P00085442       0  0-17          10             A
# 4  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
## Now handling Age
merged_df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
# pd.get_dummies(merged_df['Age'],drop_first = True) (not a good practice to do)

# we will perform here target ordinal encoding
# here we assign the ranges of age to a certain constant value according to there more visiting for shopping

merged_df['Age']  = merged_df['Age'].map({'0-17':1,'18-25':2,'26-35':3,'36-45':4,'46-50':5,'51-55':6,'55+':7})

# %%
# #Second method
# from sklearn.preprocessing import LabelEncoder

# le = LabelEncoder()

# merged_df['Age'] = le.fit_transform(merged_df['Age'])
# merged_df['Age'].unique()

# %%
merged_df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
df_city = pd.get_dummies(merged_df['City_Category'],drop_first=True)

# %%
df_city.head()
# Out:
#        B      C
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False   True

# %%
merged_df = pd.concat([merged_df,df_city],axis=1)

# %%
merged_df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase      B      C
# 0                 NaN                 NaN    8370.0  False  False
# 1                 6.0                14.0   15200.0  False  False
# ...

# %%
#droping city catagory as we can manage 3 cities with only 2 catagorical variables
merged_df.drop('City_Category',axis=1)
# Out:
#        Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0       P00069042       0    1          10                          2
# 1       P00248942       0    1          10                          2
# 2       P00087842       0    1          10                          2
# 3       P00085442       0    1          10                          2
# 4       P00285442       1    7          16                         4+
# ...           ...     ...  ...         ...                        ...
# 233594  P00118942       0    3          15                         4+
# 233595  P00254642       0    3          15                         4+
# 233596  P00031842       0    3          15                         4+
# 233597  P00124742       0    5           1                         4+
# 233598  P00316642       0    5           0                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
# missing values
merged_df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# B                                  0
# C                                  0
# dtype: int64

# %%
# purchase null values should not be in count as that should be null
# focus on replacing missing values
merged_df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9, 20, 19])

# %%
merged_df['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
# now we have to replace the missing values
merged_df['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
merged_df['Product_Category_2'].value_counts()
# Out:
# Product_Category_2
# 8.0     91317
# 14.0    78834
# 2.0     70498
# 16.0    61687
# 15.0    54114
# 5.0     37165
# 4.0     36705
# 6.0     23575
# 11.0    20230
# 17.0    19104
# 13.0    15054
# 9.0      8177
# 12.0     7801
# 10.0     4420
# 3.0      4123
# 18.0     4027
# 7.0       854
# Name: count, dtype: int64

# %%
# product catagory 2 replacing missing  values
merged_df['Product_Category_2'] = merged_df['Product_Category_2'].fillna(merged_df['Product_Category_2'].mode()[0])

# %%
merged_df['Product_Category_2'].mode()[0]
# Out:
# np.float64(8.0)

# %%
merged_df['Product_Category_2'].isnull().sum()
# Out:
# np.int64(0)

# %%
#product catagory 3 replace missing values
merged_df['Product_Category_3'].unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
merged_df['Product_Category_3'].value_counts()
# Out:
# Product_Category_3
# 16.0    46469
# 15.0    39968
# 14.0    26283
# 17.0    23818
# 5.0     23799
# 8.0     17861
# 9.0     16532
# 12.0    13115
# 13.0     7849
# 6.0      6888
# 18.0     6621
# 4.0      2691
# 11.0     2585
# 10.0     2501
# 3.0       878
# Name: count, dtype: int64

# %%
merged_df['Product_Category_3'] = merged_df['Product_Category_3'].fillna(merged_df['Product_Category_3'].mode()[0])

# %%
merged_df['Product_Category_3'].mode()[0]
# Out:
# np.float64(16.0)

# %%
merged_df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase      B      C
# 0                 8.0                16.0    8370.0  False  False
# 1                 6.0                14.0   15200.0  False  False
# ...

# %%
merged_df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
merged_df['Stay_In_Current_City_Years'] = merged_df['Stay_In_Current_City_Years'].str.replace('+','')

# %%
merged_df['Stay_In_Current_City_Years']
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         4
#          ..
# 233594    4
# 233595    4
# 233596    4
# 233597    4
# 233598    4
# Name: Stay_In_Current_City_Years, Length: 783667, dtype: object

# %%
# to convert object into integer
merged_df['Stay_In_Current_City_Years'] = merged_df['Stay_In_Current_City_Years'].astype(int)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 783667 entries, 0 to 233598
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  int64
#  2   Age                         783667 non-null  int64
#  3   Occupation                  783667 non-null  int64
#  4   City_Category               783667 non-null  object
#  5   Stay_In_Current_City_Years  783667 non-null  int64
#  6   Marital_Status              783667 non-null  int64
#  7   Product_Category_1          783667 non-null  int64
#  8   Product_Category_2          783667 non-null  float64
#  9   Product_Category_3          783667 non-null  float64
#  10  Purchase                    550068 non-null  float64
#  11  B                           783667 non-null  bool
#  12  C                           783667 non-null  bool
# ...

# %%
merged_df['B'] = merged_df['B'].astype(int)
merged_df['C'] = merged_df['C'].astype(int)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 783667 entries, 0 to 233598
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  int64
#  2   Age                         783667 non-null  int64
#  3   Occupation                  783667 non-null  int64
#  4   City_Category               783667 non-null  object
#  5   Stay_In_Current_City_Years  783667 non-null  int64
#  6   Marital_Status              783667 non-null  int64
#  7   Product_Category_1          783667 non-null  int64
#  8   Product_Category_2          783667 non-null  float64
#  9   Product_Category_3          783667 non-null  float64
#  10  Purchase                    550068 non-null  float64
#  11  B                           783667 non-null  int64
#  12  C                           783667 non-null  int64
# ...

# %%
# visualization
sns.pairplot(merged_df)

# %%
sns.barplot(x='Age',y='Purchase',hue = 'Gender',data=merged_df)
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %%
# purchasing of men and women
sns.barplot(x='Occupation',y='Purchase',hue = 'Gender',data=merged_df)
# Out:
# <Axes: xlabel='Occupation', ylabel='Purchase'>

# %%
# purchasing for product catagory 1
sns.barplot(x='Product_Category_1',y='Purchase',hue = 'Gender',data=merged_df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='Purchase'>

# %%
sns.barplot(x='Product_Category_2',y='Purchase',hue = 'Gender',data=merged_df)
# Out:
# <Axes: xlabel='Product_Category_2', ylabel='Purchase'>

# %%
sns.barplot(x='Product_Category_3',y='Purchase',hue = 'Gender',data=merged_df)
# Out:
# <Axes: xlabel='Product_Category_3', ylabel='Purchase'>

# %%
merged_df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# 3                           2               0                  12
# 4                           4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase  B  C
# 0                 8.0                16.0    8370.0  0  0
# 1                 6.0                14.0   15200.0  0  0
# 2                 8.0                16.0    1422.0  0  0
# ...

# %%
# Now feature scaling
merged_df[merged_df['Purchase'].isnull()]
# Out:
#        Product_ID  Gender  Age  Occupation City_Category  \
# 0       P00128942       1    5           7             B
# 1       P00113442       1    3          17             C
# 2       P00288442       0    4           1             B
# 3       P00145342       0    4           1             B
# 4       P00053842       0    3           1             C
# ...           ...     ...  ...         ...           ...
# 233594  P00118942       0    3          15             B
# 233595  P00254642       0    3          15             B
# 233596  P00031842       0    3          15             B
# 233597  P00124742       0    5           1             C
# 233598  P00316642       0    5           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               1                   1
# 1                                0               0                   3
# ...

# %%
df_train = merged_df[~merged_df['Purchase'].isnull()]

# %%
X= df_train.drop('Purchase',axis=1)
X.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# 3                           2               0                  12
# 4                           4               0                   8
#
#    Product_Category_2  Product_Category_3  B  C
# 0                 8.0                16.0  0  0
# 1                 6.0                14.0  0  0
# 2                 8.0                16.0  0  0
# 3                14.0                16.0  0  0
# ...

# %%
X.shape
# Out:
# (550068, 12)

# %%
Y = df_train[::-1]
Y.head()
# Out:
#        Product_ID  Gender  Age  Occupation City_Category  \
# 550067  P00371644       0    5           0             B
# 550066  P00375436       0    7           1             C
# 550065  P00375436       0    3          15             B
# 550064  P00375436       0    3           1             C
# 550063  P00372445       1    6          13             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550067                           4               1                  20
# 550066                           2               0                  20
# 550065                           4               1                  20
# 550064                           3               0                  20
# 550063                           1               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase  B  C
# 550067                 8.0                16.0     490.0  1  0
# 550066                 8.0                16.0     365.0  0  1
# ...

# %%
Y.shape
# Out:
# (550068, 13)

# %%
merged_df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# 3                           2               0                  12
# 4                           4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase  B  C
# 0                 8.0                16.0    8370.0  0  0
# 1                 6.0                14.0   15200.0  0  0
# 2                 8.0                16.0    1422.0  0  0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
X_train.drop('Product_ID',axis=1,inplace=True)
X_test.drop('Product_ID',axis=1,inplace=True)

# %%
X_train.drop('City_Category',axis=1,inplace=True)
X_test.drop('City_Category',axis=1,inplace=True)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_tarin = sc.fit_transform(X_train)

X_test = sc.transform(X_test)

# %%
# EDA is done now Train Your Model

# %% [markdown]
# # **Flight Price Perdiction EDA**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_df=pd.read_excel('/content/Data_Train.xlsx')
train_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
test_df = pd.read_excel('/content/Test_set.xlsx')
test_df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
final_df = pd.concat([train_df,test_df])
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
final_df.tail()
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2666          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2667             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2668        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2669          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 2666    20:30  20:25 07 Jun  23h 55m      1 stop         No info    NaN
# 2667    14:20         16:55   2h 35m    non-stop         No info    NaN
# 2668    21:50  04:25 07 Mar   6h 35m      1 stop         No info    NaN
# 2669    04:00         19:15  15h 15m      1 stop         No info    NaN
# 2670    04:55         19:15  14h 20m      1 stop         No info    NaN

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.7+ MB

# %%
from typing_extensions import final
# Feature Engineering
final_df['Date'] = final_df['Date_of_Journey'].str.split('/').str[0]
final_df['Month'] = final_df['Date_of_Journey'].str.split('/').str[1]
final_df['Year'] = final_df['Date_of_Journey'].str.split('/').str[2]

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0   01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# ...

# %%
final_df['Date'] = final_df['Date'].astype(int)
final_df['Month'] = final_df['Month'].astype(int)
final_df['Year'] = final_df['Year'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  int64
#  12  Month            13354 non-null  int64
#  13  Year             13354 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 2.0+ MB

# %%
final_df.drop(['Date_of_Journey'],axis=1,inplace=True)

# %%
final_df.head(10)
# Out:
#              Airline    Source Destination                  Route Dep_Time  \
# 0             IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1          Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2        Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3             IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4             IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# 5           SpiceJet   Kolkata    Banglore              CCU → BLR    09:00
# 6        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    18:55
# 7        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    08:00
# 8        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    08:55
# 9  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    11:25
#
#    Arrival_Time Duration Total_Stops              Additional_Info    Price  \
# ...

# %%
final_df['Arrival_Time'] = final_df['Arrival_Time'].str.split(' ').str[0]

# %%
final_df['Arrival_Time']
# Out:
# 0       01:10
# 1       13:15
# 2       04:25
# 3       23:30
# 4       21:35
#         ...
# 2666    20:25
# 2667    16:55
# 2668    04:25
# 2669    19:15
# 2670    19:15
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
final_df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# Date                  0
# Month                 0
# Year                  0
# dtype: int64

# %%
final_df['hrs'] = final_df['Arrival_Time'].str.split(':').str[0]
final_df['min'] = final_df['Arrival_Time'].str.split(':').str[1]

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m    non-stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year hrs min
# 0  2019  01  10
# 1  2019  13  15
# 2  2019  04  25
# 3  2019  23  30
# 4  2019  21  35

# %%
final_df['Arrival_hrs'] = final_df['hrs'].astype(int)
final_df['Arrival_min'] = final_df['min'].astype(int)
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  Date             13354 non-null  int64
#  11  Month            13354 non-null  int64
#  12  Year             13354 non-null  int64
#  13  hrs              13354 non-null  object
#  14  min              13354 non-null  object
#  15  Arrival_hrs      13354 non-null  int64
#  16  Arrival_min      13354 non-null  int64
# ...

# %%
final_df.drop(['hrs'],axis=1,inplace=True)
final_df.drop(['min'],axis=1,inplace=True)

# %%
final_df.head(10)
# Out:
#              Airline    Source Destination                  Route Dep_Time  \
# 0             IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1          Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2        Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3             IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4             IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# 5           SpiceJet   Kolkata    Banglore              CCU → BLR    09:00
# 6        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    18:55
# 7        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    08:00
# 8        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    08:55
# 9  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    11:25
#
#   Arrival_Time Duration Total_Stops              Additional_Info    Price  \
# ...

# %%
final_df['hrs'] = final_df['Dep_Time'].str.split(':').str[0]
final_df['min'] = final_df['Dep_Time'].str.split(':').str[1]
final_df['Dep_hrs'] = final_df['hrs'].astype(int)
final_df['Dep_min'] = final_df['min'].astype(int)
final_df.drop(['hrs'],axis=1,inplace=True)
final_df.drop(['min'],axis=1,inplace=True)
final_df.drop(['Dep_Time'],axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL        01:10
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR        13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK        04:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR        23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL        21:35
#
#   Duration Total_Stops Additional_Info    Price  Date  Month  Year  \
# 0   2h 50m    non-stop         No info   3897.0    24      3  2019
# 1   7h 25m     2 stops         No info   7662.0     1      5  2019
# 2      19h     2 stops         No info  13882.0     9      6  2019
# 3   5h 25m      1 stop         No info   6218.0    12      5  2019
# 4   4h 45m      1 stop         No info  13302.0     1      3  2019
#
#    Arrival_hrs  Arrival_min  Dep_hrs  Dep_min
# 0            1           10       22       20
# ...

# %%
# Here we can take route and do FeatureEngineering for that we can just count number of stops
# or delete the route

final_df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
final_df['Total_Stops'] = final_df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4})

# %%
final_df[final_df['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Route Arrival_Time Duration  Total_Stops  \
# 9039  Air India  Delhi      Cochin   NaN        09:25  23h 40m          NaN
#
#      Additional_Info   Price  Date  Month  Year  Arrival_hrs  Arrival_min  \
# 9039         No info  7480.0     6      5  2019            9           25
#
#       Dep_hrs  Dep_min
# 9039        9       45

# %%
final_df.drop(['Route'],axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination Arrival_Time Duration  Total_Stops  \
# 0       IndiGo  Banglore   New Delhi        01:10   2h 50m          0.0
# 1    Air India   Kolkata    Banglore        13:15   7h 25m          2.0
# 2  Jet Airways     Delhi      Cochin        04:25      19h          2.0
# 3       IndiGo   Kolkata    Banglore        23:30   5h 25m          1.0
# 4       IndiGo  Banglore   New Delhi        21:35   4h 45m          1.0
#
#   Additional_Info    Price  Date  Month  Year  Arrival_hrs  Arrival_min  \
# 0         No info   3897.0    24      3  2019            1           10
# 1         No info   7662.0     1      5  2019           13           15
# 2         No info  13882.0     9      6  2019            4           25
# 3         No info   6218.0    12      5  2019           23           30
# 4         No info  13302.0     1      3  2019           21           35
#
#    Dep_hrs  Dep_min
# 0       22       20
# 1        5       50
# 2        9       25
# ...

# %%
final_df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Arrival_Time     13354 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  float64
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   Date             13354 non-null  int64
#  9   Month            13354 non-null  int64
#  10  Year             13354 non-null  int64
#  11  Arrival_hrs      13354 non-null  int64
#  12  Arrival_min      13354 non-null  int64
#  13  Dep_hrs          13354 non-null  int64
#  14  Dep_min          13354 non-null  int64
# dtypes: float64(2), int64(7), object(6)
# memory usage: 2.1+ MB

# %%
final_df['duration_hrs'] = final_df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
final_df[final_df['Duration']=='5m']
# Out:
#         Airline  Source Destination Arrival_Time Duration  Total_Stops  \
# 6474  Air India  Mumbai   Hyderabad        16:55       5m          2.0
# 2660  Air India  Mumbai   Hyderabad        16:55       5m          2.0
#
#      Additional_Info    Price  Date  Month  Year  Arrival_hrs  Arrival_min  \
# 6474         No info  17327.0     6      3  2019           16           55
# 2660         No info      NaN    12      3  2019           16           55
#
#       Dep_hrs  Dep_min duration_hrs
# 6474       16       50           5m
# 2660       16       50           5m

# %%
final_df.drop(6474,axis=0,inplace=True)
final_df.drop(2660,axis=0,inplace=True)

# %%
final_df['duration_hrs']=final_df['duration_hrs'].astype(int)

# %%
final_df.drop(['Duration'],axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination Arrival_Time  Total_Stops  \
# 0       IndiGo  Banglore   New Delhi        01:10          0.0
# 1    Air India   Kolkata    Banglore        13:15          2.0
# 2  Jet Airways     Delhi      Cochin        04:25          2.0
# 3       IndiGo   Kolkata    Banglore        23:30          1.0
# 4       IndiGo  Banglore   New Delhi        21:35          1.0
#
#   Additional_Info    Price  Date  Month  Year  Arrival_hrs  Arrival_min  \
# 0         No info   3897.0    24      3  2019            1           10
# 1         No info   7662.0     1      5  2019           13           15
# 2         No info  13882.0     9      6  2019            4           25
# 3         No info   6218.0    12      5  2019           23           30
# 4         No info  13302.0     1      3  2019           21           35
#
#    Dep_hrs  Dep_min  duration_hrs
# 0       22       20             2
# 1        5       50             7
# 2        9       25            19
# ...

# %%
final_df['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
final_df['Airline'] = le.fit_transform(final_df['Airline'])
final_df['Source'] = le.fit_transform(final_df['Source'])
final_df['Destination'] = le.fit_transform(final_df['Destination'])
final_df['Additional_Info'] = le.fit_transform(final_df['Additional_Info'])

# %%
final_df.shape
# Out:
# (13351, 15)

# %%
final_df.head(2)
# Out:
#    Airline  Source  Destination Arrival_Time  Total_Stops  Additional_Info  \
# 0        3       0            5        01:10          0.0                8
# 1        1       3            0        13:15          2.0                8
#
#     Price  Date  Month  Year  Arrival_hrs  Arrival_min  Dep_hrs  Dep_min  \
# 0  3897.0    24      3  2019            1           10       22       20
# 1  7662.0     1      5  2019           13           15        5       50
#
#    duration_hrs
# 0             2
# 1             7

# %%
df1 = pd.get_dummies(final_df['Airline'])
df2 = pd.get_dummies(final_df['Source'])
df3 = pd.get_dummies(final_df['Destination'])
df4 = pd.get_dummies(final_df['Additional_Info'])

# %%
final_df.head(2)
# Out:
#    Airline  Source  Destination Arrival_Time  Total_Stops  Additional_Info  \
# 0        3       0            5        01:10          0.0                8
# 1        1       3            0        13:15          2.0                8
#
#     Price  Date  Month  Year  Arrival_hrs  Arrival_min  Dep_hrs  Dep_min  \
# 0  3897.0    24      3  2019            1           10       22       20
# 1  7662.0     1      5  2019           13           15        5       50
#
#    duration_hrs
# 0             2
# 1             7

# %%
pd.concat([final_df,df1,df2,df3,df4])
# Out:
#       Airline  Source  Destination Arrival_Time  Total_Stops  Additional_Info  \
# 0         3.0     0.0          5.0        01:10          0.0              8.0
# 1         1.0     3.0          0.0        13:15          2.0              8.0
# 2         4.0     2.0          1.0        04:25          2.0              8.0
# 3         3.0     3.0          0.0        23:30          1.0              8.0
# 4         3.0     0.0          5.0        21:35          1.0              8.0
# ...       ...     ...          ...          ...          ...              ...
# 2666      NaN     NaN          NaN          NaN          NaN              NaN
# 2667      NaN     NaN          NaN          NaN          NaN              NaN
# 2668      NaN     NaN          NaN          NaN          NaN              NaN
# 2669      NaN     NaN          NaN          NaN          NaN              NaN
# 2670      NaN     NaN          NaN          NaN          NaN              NaN
#
# ...

# %%
pd.get_dummies(final_df,columns=['Airline','Source','Destination','Additional_Info'],drop_first=True)
# Out:
#       Total_Stops    Price  Date  Month  Year  Arrival_hrs  Arrival_min  \
# 0             0.0   3897.0    24      3  2019            1           10
# 1             2.0   7662.0     1      5  2019           13           15
# 2             2.0  13882.0     9      6  2019            4           25
# 3             1.0   6218.0    12      5  2019           23           30
# 4             1.0  13302.0     1      3  2019           21           35
# ...           ...      ...   ...    ...   ...          ...          ...
# 2666          1.0      NaN     6      6  2019           20           25
# 2667          0.0      NaN    27      3  2019           16           55
# 2668          1.0      NaN     6      3  2019            4           25
# 2669          1.0      NaN     6      3  2019           19           15
# 2670          1.0      NaN    15      6  2019           19           15
#
#       Dep_hrs  Dep_min  duration_hrs  ...  Destination_5  Additional_Info_1  \
# ...

# %%
final_df.drop(['Arrival_Time'], axis=1, inplace=True)
